# %%
import numpy as np
data = [np.random.standard_normal() for i in range(7)]
data
# Out:
# [-0.7741448270508235,
#  -0.6375076782082125,
#  0.17166375821993773,
#  -1.7950744345255174,
#  -1.1610267710895525,
#  0.629878829254179,
#  0.1707081546445034]
