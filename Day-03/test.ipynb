# %%
import numpy as np
data = [np.random.standard_normal() for i in range(7)]
data
# Out:
# [-1.8208401874715916,
#  0.08404709133868718,
#  0.07887583276893032,
#  -0.6865514961081634,
#  -1.5453558740181248,
#  -0.18983789141728874,
#  1.9993526884826798]
